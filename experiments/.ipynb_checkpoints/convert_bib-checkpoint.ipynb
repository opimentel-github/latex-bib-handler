# %%
import sys
sys.path.append('../') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from bibhandler.handlers import RefsHandler

filedir = '../data/references.bib'
invalid_attrs = ['url', 'abstract', 'annote']
refs_handler = RefsHandler(filedir, invalid_attrs)
print(refs_handler)
refs_handler.export('../save')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# @inproceedings{Tishby2015,
# year = {2015},
# title = {Deep learning and the information bottleneck principle},
# doi = {10.1109/ITW.2015.7133169},
# booktitle = {2015 IEEE Information Theory Workshop, ITW 2015},
# author = {Tishby, Naftali and Zaslavsky, Noga},
# }
# @article{Alcock1996,
# year = {1996},
# volume = {461},
# title = {The MACHO Project First-Year Large Magellanic Cloud Results: The Microlensing Rate and the Nature of the Galactic Dark Halo},
# pages = {84},
# month = {apr},
# mendeley-tags = {so},
# keywords = {so},
# journal = {The Astrophysical Journal},
# issn = {0004-637X},
# doi = {10.1086/177039},
# ...
